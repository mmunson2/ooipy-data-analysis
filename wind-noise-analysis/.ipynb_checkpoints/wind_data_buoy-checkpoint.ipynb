# %%
import numpy as np
import json
from matplotlib import pyplot as plt
from obspy import read,Stream, Trace
from obspy.core import UTCDateTime
import math as M
from matplotlib import mlab
from matplotlib.colors import Normalize
import requests
from lxml import html
from scipy import signal
import matplotlib.colors as colors
import datetime
from scipy import signal
import requests
import urllib
import datetime
import time as tm
import pandas as pd
import function_lib as lib
import matplotlib.dates as mdates
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-957cfbb2f018> in <module>
#      18 import time as tm
#      19 import pandas as pd
# ---> 20 import function_lib as lib
#      21 import matplotlib.dates as mdates
#      22 import os
#
# ~/GitHub/ooipy-data-analysis/wind-noise-analysis/function_lib.py in <module>
#      27 #!pip install thredds_crawler
#      28 #!sudo python3 -m pip install thredds_crawler
# ---> 29 from thredds_crawler.crawl import Crawl
#      30
#      31 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'thredds_crawler'

# %%
def smoothen_data2_revised(L, data, win):
    if win == "rect":
        ma_filter = np.ones(L) / L
    elif win == "hann":
        if L % 2 == 0: L = L + 1
        ma_filter = signal.hann(L, True)
        ma_filter = ma_filter / np.sum(ma_filter)
    
    data_smooth = np.convolve(data, ma_filter, 'same')
        
    return data_smooth

# %% [markdown]
# ## Oregon Offshore

# %%
## get URLs for mooring data
urls_offshore = lib.web_crawler_mooring('2015-05-01T00:00:00.000Z', '2020-02-20T12:00:00.000Z', location='offshore')
# Out:
# telemetered
# {'requestUUID': '78a31ac4-1e07-4d6f-a88b-7805a0465059', 'outputURL': 'https://opendap.oceanobservatories.org/thredds/catalog/ooi/fschwock@uw.edu/20210406T222220523Z-CE04OSSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument/catalog.html', 'allURLs': ['https://opendap.oceanobservatories.org/thredds/catalog/ooi/fschwock@uw.edu/20210406T222220523Z-CE04OSSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument/catalog.html', 'https://opendap.oceanobservatories.org/async_results/fschwock@uw.edu/20210406T222220523Z-CE04OSSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument'], 'sizeCalculation': 177918760, 'timeCalculation': 60, 'numberOfSubJobs': 64}
# request completed

# %%
# get mooring data
print(urls_offshore)
data_offshore = lib.get_mooring_data(urls_offshore)
# Out:
# ['https://opendap.oceanobservatories.org/thredds/fileServer/ooi/fschwock@uw.edu/20210406T222220523Z-CE04OSSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument/deployment0001_CE04OSSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument_20150501T000049-20150517T235939.csv', 'https://opendap.oceanobservatories.org/thredds/fileServer/ooi/fschwock@uw.edu/20210406T222220523Z-CE04OSSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument/deployment0001_CE04OSSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument_20150518T000012-20150614T235901.csv', 'https://opendap.oceanobservatories.org/thredds/fileServer/ooi/fschwock@uw.edu/20210406T222220523Z-CE04OSSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument/deployment0001_CE04OSSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument_20150615T000005-20150712T235929.csv', 'https://opendap.oceanobservatories.org/thredds/fileServer/ooi/fschwock@uw.edu/20210406T222220523Z-CE04OSSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument/deployment0001_CE04OSSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument_20150713T000034-20150809T235919.csv', 'https://opendap.oceanobservatories.org/thredds/fileServer/ooi/fschwock@uw.edu/20210406T222220523Z-CE04OSSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument/deployment0001_CE04OSSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument_20150810T000025-20150906T235942.csv', 'https://opendap.oceanobservatories.org/thredds/fileServer/ooi/fschwock@uw.edu/20210406T222220523Z-CE04OSSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument/deployment0001_CE04OSSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument_20150907T000046-20151004T235921.csv', 'https://opendap.oceanobservatories.org/thredds/fileServer/ooi/fschwock@uw.edu/20210406T222220523Z-CE04OSSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument/deployment0001_CE04OSSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument_20151005T000026-20151101T235959.csv', 'https://opendap.oceanobservatories.org/thredds/fileServer/ooi/fschwock@uw.edu/20210406T222220523Z-CE04OSSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument/deployment0001_CE04OSSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument_20151102T000103-20151129T235943.csv', 'https://opendap.oceanobservatories.org/thredds/fileServer/ooi/fschwock@uw.edu/20210406T222220523Z-CE04OSSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument/deployment0001_CE04OSSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument_20151130T000047-20151223T192828.csv', 'https://opendap.oceanobservatories.org/thredds/fileServer/ooi/fschwock@uw.edu/20210406T222220523Z-CE04OSSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument/deployment0002_CE04OSSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument_20160516T051050-20160612T235926.csv', 'https://opendap.oceanobservatories.org/thredds/fileServer/ooi/fschwock@uw.edu/20210406T222220523Z-CE04OSSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument/deployment0002_CE04OSSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument_20160613T000000-20160710T235950.csv', 'https://opendap.oceanobservatories.org/thredds/fileServer/ooi/fschwock@uw.edu/20210406T222220523Z-CE04OSSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument/deployment0002_CE04OSSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument_20160711T000055-20160807T235904.csv', 'https://opendap.oceanobservatories.org/thredds/fileServer/ooi/fschwock@uw.edu/20210406T222220523Z-CE04OSSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument/deployment0002_CE04OSSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument_20160808T000009-20160904T235953.csv', 'https://opendap.oceanobservatories.org/thredds/fileServer/ooi/fschwock@uw.edu/20210406T222220523Z-CE04OSSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument/deployment0002_CE04OSSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument_20160905T000058-20161001T152043.csv', 'https://opendap.oceanobservatories.org/thredds/fileServer/ooi/fschwock@uw.edu/20210406T222220523Z-CE04OSSM ...

# %%
# convert seconds to datetime
time_offshore = data_offshore.time
time_offshore = time_offshore.apply(lib.ntp_seconds_to_datetime)

# get wind data
wind_mag_offshore = np.sqrt((data_offshore.eastward_wind_velocity)**2 + (data_offshore.northward_wind_velocity)**2)
wind_angle_offshore = np.arctan2(data_offshore.northward_wind_velocity, data_offshore.eastward_wind_velocity)

# %%
# smoothen wind data
wind_vec_offshore = wind_mag_offshore * np.exp(1j * wind_angle_offshore)
wind_vec_smooth_offshore = smoothen_data2_revised(21, wind_vec_offshore, 'hann')
wind_mag_smooth_offshore = abs(wind_vec_smooth_offshore) # wind speed (smoothed)
wind_angle_smooth_offshore = np.angle(wind_vec_smooth_offshore) # wind angle rel. to eastward direction (smoothed)

# plot 200 samples (i.e. 200 min) of smoothed wind speed
plt.plot(time_offshore[1000:1200], wind_mag_smooth_offshore[1000:1200])
plt.grid()
plt.xlabel('time')
plt.ylabel('wind speed [m/s]')
# Out:
# Text(0, 0.5, 'wind speed [m/s]')

# %% [markdown]
# ## Oregon Shelf

# %%
## get URLs for mooring data
urls_shelf = lib.web_crawler_mooring('2015-05-01T00:00:00.000Z', '2020-02-20T12:00:00.000Z', location='shelf')
# Out:
# telemetered
# {'requestUUID': '64c4caef-efcd-4ded-865c-1ba5eebce5e4', 'outputURL': 'https://opendap.oceanobservatories.org/thredds/catalog/ooi/fschwock@uw.edu/20210407T002238487Z-CE02SHSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument/catalog.html', 'allURLs': ['https://opendap.oceanobservatories.org/thredds/catalog/ooi/fschwock@uw.edu/20210407T002238487Z-CE02SHSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument/catalog.html', 'https://opendap.oceanobservatories.org/async_results/fschwock@uw.edu/20210407T002238487Z-CE02SHSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument'], 'sizeCalculation': 218955227, 'timeCalculation': 60, 'numberOfSubJobs': 64}
# request completed

# %%
# get mooring data
print(urls_shelf)
data_shelf = lib.get_mooring_data(urls_shelf)
# Out:
# ['https://opendap.oceanobservatories.org/thredds/fileServer/ooi/fschwock@uw.edu/20210407T002238487Z-CE02SHSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument/deployment0001_CE02SHSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument_20150501T000031-20150517T235924.csv', 'https://opendap.oceanobservatories.org/thredds/fileServer/ooi/fschwock@uw.edu/20210407T002238487Z-CE02SHSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument/deployment0001_CE02SHSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument_20150518T000028-20150614T235917.csv', 'https://opendap.oceanobservatories.org/thredds/fileServer/ooi/fschwock@uw.edu/20210407T002238487Z-CE02SHSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument/deployment0001_CE02SHSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument_20150615T000021-20150712T235929.csv', 'https://opendap.oceanobservatories.org/thredds/fileServer/ooi/fschwock@uw.edu/20210407T002238487Z-CE02SHSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument/deployment0001_CE02SHSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument_20150713T000034-20150809T235934.csv', 'https://opendap.oceanobservatories.org/thredds/fileServer/ooi/fschwock@uw.edu/20210407T002238487Z-CE02SHSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument/deployment0001_CE02SHSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument_20150810T000038-20150825T180337.csv', 'https://opendap.oceanobservatories.org/thredds/fileServer/ooi/fschwock@uw.edu/20210407T002238487Z-CE02SHSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument/deployment0002_CE02SHSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument_20151007T211021-20151101T235910.csv', 'https://opendap.oceanobservatories.org/thredds/fileServer/ooi/fschwock@uw.edu/20210407T002238487Z-CE02SHSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument/deployment0002_CE02SHSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument_20151102T000015-20151129T235908.csv', 'https://opendap.oceanobservatories.org/thredds/fileServer/ooi/fschwock@uw.edu/20210407T002238487Z-CE02SHSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument/deployment0002_CE02SHSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument_20151130T000012-20151227T235950.csv', 'https://opendap.oceanobservatories.org/thredds/fileServer/ooi/fschwock@uw.edu/20210407T002238487Z-CE02SHSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument/deployment0002_CE02SHSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument_20151228T000055-20160124T235940.csv', 'https://opendap.oceanobservatories.org/thredds/fileServer/ooi/fschwock@uw.edu/20210407T002238487Z-CE02SHSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument/deployment0002_CE02SHSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument_20160125T000044-20160221T235958.csv', 'https://opendap.oceanobservatories.org/thredds/fileServer/ooi/fschwock@uw.edu/20210407T002238487Z-CE02SHSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument/deployment0002_CE02SHSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument_20160222T000102-20160320T235953.csv', 'https://opendap.oceanobservatories.org/thredds/fileServer/ooi/fschwock@uw.edu/20210407T002238487Z-CE02SHSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument/deployment0002_CE02SHSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument_20160321T000058-20160417T235923.csv', 'https://opendap.oceanobservatories.org/thredds/fileServer/ooi/fschwock@uw.edu/20210407T002238487Z-CE02SHSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument/deployment0002_CE02SHSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument_20160418T000028-20160515T235945.csv', 'https://opendap.oceanobservatories.org/thredds/fileServer/ooi/fschwock@uw.edu/20210407T002238487Z-CE02SHSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument/deployment0002_CE02SHSM-SBD11-06-METBKA000-telemetered-metbk_a_dcl_instrument_20160516T000017-20160516T180930.csv', 'https://opendap.oceanobservatories.org/thredds/fileServer/ooi/fschwock@uw.edu/20210407T002238487Z-CE02SHSM ...

# %%
# convert seconds to datetime
time_shelf = data_shelf.time
time_shelf = time_shelf.apply(lib.ntp_seconds_to_datetime)

# get wind data
wind_mag_shelf = np.sqrt((data_shelf.eastward_wind_velocity)**2 + (data_shelf.northward_wind_velocity)**2)
wind_angle_shelf = np.arctan2(data_shelf.northward_wind_velocity, data_shelf.eastward_wind_velocity)

# %%
# smoothen wind data
wind_vec_shelf = wind_mag_shelf * np.exp(1j * wind_angle_shelf)
wind_vec_smooth_shelf = smoothen_data2_revised(21, wind_vec_shelf, 'hann')
wind_mag_smooth_shelf = abs(wind_vec_smooth_shelf) # wind speed (smoothed)
wind_angle_smooth_shelf = np.angle(wind_vec_smooth_shelf) # wind angle rel. to eastward direction (smoothed)

# plot 200 samples (i.e. 200 min) of smoothed wind speed
plt.plot(time_shelf[1000:1200], wind_mag_smooth_shelf[1000:1200])
plt.grid()
plt.xlabel('time')
plt.ylabel('wind speed [m/s]')
# Out:
# Text(0, 0.5, 'wind speed [m/s]')
